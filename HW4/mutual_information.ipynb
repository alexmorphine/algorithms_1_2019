# %%
# %matplotlib inline
from mutual_information import MutualInformation
from test_mutual_information import TestMU
import warnings
warnings.filterwarnings('ignore')

# %%
m = MutualInformation("eukaryotic-tRNAs.fa")
# Out:
# To have no NaNs in fasta, please select x and y which are less than 59

# %%
m.mutual_information(4, 5)
# Out:
# Mutual information for columns 4 and 5 is 0.1318734450159437

# %%
# описания тестов в файле test_mutual_information
test = TestMU()

# %%
test.run()
# Out:
# To have no NaNs in fasta, please select x and y which are less than 8
# To have no NaNs in fasta, please select x and y which are less than 68
# To have no NaNs in fasta, please select x and y which are less than 71
# To have no NaNs in fasta, please select x and y which are less than 59
# To have no NaNs in fasta, please select x and y which are less than 59
